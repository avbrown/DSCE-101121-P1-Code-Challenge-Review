# %%
#Run this Cell with No Changes 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from numbers import Number
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1) Read the mpg_final CSV File into a Pandas DataFrame Called df
#
# Hint:  Make sure the data folder is in the same directory as this notebook and use 'data/mpg_final.csv'

# %%
#Starter Code 

df = pd.read_csv('data/mpg_final.csv')
display(df)
display(df.info())
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name       make
# 0            70     usa  chevrolet chevelle malibu  chevrolet
# 1            70     usa          buick skylark 320      buick
# 2            70     usa         plymouth satellite   plymouth
# 3            70     usa              amc rebel sst        amc
# 4            70     usa                ford torino       ford
# ..          ...     ...                        ...        ...
# 393          82     usa            ford mustang gl       ford
# 394          82  europe                  vw pickup         vw
# 395          82     usa              dodge rampage      dodge
# 396          82     usa                ford ranger       ford
# 397          82     usa                 chevy s-10      chevy
#
# [398 rows x 10 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
#  9   make          398 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 31.2+ KB
# None

# %% [markdown]
# ## 1.1). Drop the missing values from the 'horsepower' column

# %%
##Begin Solution 

df = df.dropna(axis=0, subset=['horsepower'])
display(df.info())

##End Solution
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
#  9   make          392 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 33.7+ KB
# None

# %% [markdown]
# ## 1.2) Divide the Weight column by 2.205 to turn it into kilograms call this new column 'weight_kg'

# %%
##Begin Solution 

df['weight_kg'] = df['weight']/2.205
display(df)

##End Solution
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name       make    weight_kg
# 0            70     usa  chevrolet chevelle malibu  chevrolet  1589.115646
# 1            70     usa          buick skylark 320      buick  1674.829932
# 2            70     usa         plymouth satellite   plymouth  1558.276644
# 3            70     usa              amc rebel sst        amc  1556.916100
# 4            70     usa                ford torino       ford  1564.172336
# ..          ...     ...                        ...        ...          ...
# 393          82     usa            ford mustang gl       ford  1265.306122
# 394          82  europe                  vw pickup         vw   965.986395
# 395          82     usa              dodge rampage      dodge  1040.816327
# 396          82     usa                ford ranger       ford  1190.476190
# 397          82     usa                 chevy s-10      chevy  1233.560091
#
# [392 rows x 11 columns]

# %% [markdown]
# ## 1.3) Find the Top 2 Origins with the Most Vehicles

# %%
##Begin Solution 

top_2_origins = df['origin'].value_counts().index[0:2]
top_2_origins

##End Solution
# Out:
# Index(['usa', 'japan'], dtype='object')

# %% [markdown]
# ## Part 2) Data Visualization

# %% [markdown]
# ## 2.1 Using matplotlib create a bar chart of the Top 8 makes with the highest frequency
# ### Note:  Please include a chart title, x-label, and y-label

# %%
cars_count_figure, ax = plt.subplots(figsize=(10, 6))

##Begin Solution

display(df['make'].value_counts())
top_8_makes_txt = df['make'].value_counts().index[0:8]
top_8_makes_num = df['make'].value_counts().values[0:8]
# print(top_8_makes_txt)

ax.barh(y=top_8_makes[::-1],width=top_8_makes_num[::-1], )
ax.set_xlabel("# of Vehicles")
ax.set_ylabel("Vehicle Make")
ax.set_title("Top 8 Most Frequent Vehicle Makes");

##End Solution
# Out:
# ford             48
# chevrolet        43
# plymouth         31
# dodge            28
# amc              27
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# oldsmobile       10
# mazda            10
# peugeot           8
# fiat              8
# audi              7
# volvo             6
# chrysler          6
# vw                6
# opel              4
# saab              4
# subaru            4
# renault           3
# chevy             3
# maxda             2
# mercedes-benz     2
# bmw               2
# cadillac          2
# triumph           1
# toyouta           1
# chevroelt         1
# hi                1
# capri             1
# nissan            1
# vokswagen         1
# mercedes          1
# Name: make, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e448ceb9e6b3> in <module>
#       8 # print(top_8_makes_txt)
#       9
# ---> 10 ax.barh(y=top_8_makes[::-1],width=top_8_makes_num[::-1], )
#      11 ax.set_xlabel("# of Vehicles")
#      12 ax.set_ylabel("Vehicle Make")
#
# NameError: name 'top_8_makes' is not defined

# %% [markdown]
# ## 2.2 Create a ScatterPlot of Horsepower to MPG
# ### Note:  Please include a chart title, x-label, y-label

# %%
cars_count_figure, ax = plt.subplots(figsize=(10, 6))

##Begin Solution 

ax.scatter(x=df['mpg'], y=df['horsepower'])
ax.set_xlabel("MPG")
ax.set_ylabel("Horsepower")
ax.set_title("Horsepower vs. MPG");

##End Solution

# %% [markdown]
# ## 3). Exploring Statistical Data

# %% [markdown]
# ## 3.1) Create one variable called 'mean_acceleration' and another variable called 'median_acceleration' using the acceleration column

# %%
## Begin Solution 

mean_acceleration = round(df['acceleration'].mean(),1)
median_acceleration = df['acceleration'].median()
print(f'Mean Acceleration: \t{mean_acceleration}')
print(f'Median Acceleration: \t{median_acceleration}')

## End Solution
# Out:
# Mean Acceleration: 	15.5
# Median Acceleration: 	15.5

# %% [markdown]
# ## 3.2). Create a variable called 'oldest_ford_modelname' and 'oldest_ford_modelyear' that contains the model name and year of the oldest Ford

# %%
##Begin Solution 


fords = df.loc[df['make']=='ford', ['name', 'model_year']]
display(fords.sort_values(by='model_year'))
oldest_fords = fords.loc[fords['model_year']==fords['model_year'].min()]
oldest_fords

##End Solution
# Out:
#                          name  model_year
# 4                 ford torino          70
# 5            ford galaxie 500          70
# 17              ford maverick          70
# 25                  ford f250          70
# 36            ford torino 500          71
# 40           ford galaxie 500          71
# 43   ford country squire (sw)          71
# 48               ford mustang          71
# 80            ford pinto (sw)          72
# 74      ford gran torino (sw)          72
# 61        ford pinto runabout          72
# 65           ford galaxie 500          72
# 88           ford gran torino          73
# 92                   ford ltd          73
# 100             ford maverick          73
# 104              ford country          73
# 112                ford pinto          73
# 130                ford pinto          74
# 136          ford gran torino          74
# 139     ford gran torino (sw)          74
# 174                ford pinto          75
# 166           ford mustang ii          75
# 168                ford pinto          75
# 155             ford maverick          75
# 159                  ford ltd          75
# 190          ford gran torino          76
# 193             ford maverick          76
# 200         ford granada ghia          76
# 206                ford pinto          76
# 214                 ford f108          76
# 228              ford granada          77
# 232          ford thunderbird          77
# 236       ford mustang ii 2+2          77
# 255       ford fairmont (man)          78
# 264               ford futura          78
# 245               ford fiesta          78
# 254      ford fairmont (auto)          78
# 282           ford fairmont 4          79
# 286           ford ltd landau          79
# 290  ford country squire (sw)          79
# 314             ford fairmont          80
# 365           ford granada gl          81
# 351            ford escort 4w          81
# 352            ford escort 2h          81
# 389            ford granada l          82
# 393           ford mustang gl          82
# 373      ford fairmont futura          82
# 396               ford ranger          82
#                 name  model_year
# 4        ford torino          70
# 5   ford galaxie 500          70
# 17     ford maverick          70
# 25         ford f250          70

# %% [markdown]
# ## Part 4). Python Data Structures

# %%
##Run this cell without changes 

mpg_dict = {'chevrolet': {'mpg': 18.0,
  'cylinders': 8,
  'displacement': 307.0,
  'horsepower': 130.0,
  'weight': 3504,
  'acceleration': 12.0,
  'model_year': 70,
  'origin': 'usa'},
 'buick': {'mpg': 15.0,
  'cylinders': 8,
  'displacement': 350.0,
  'horsepower': 165.0,
  'weight': 3693,
  'acceleration': 11.5,
  'model_year': 70,
  'origin': 'europe'},
 'plymouth': {'mpg': 18.0,
  'cylinders': 8,
  'displacement': 318.0,
  'horsepower': 150.0,
  'weight': 3436,
  'acceleration': 11.0,
  'model_year': 70,
  'origin': 'canada'},
 'amc': {'mpg': 16.0,
  'cylinders': 8,
  'displacement': 304.0,
  'horsepower': 150.0,
  'weight': 3433,
  'acceleration': 12.0,
  'model_year': 70,
  'origin': 'usa'},
 'ford': {'mpg': 17.0,
  'cylinders': 8,
  'displacement': 302.0,
  'horsepower': 140.0,
  'weight': 3449,
  'acceleration': 10.5,
  'model_year': 70,
  'origin': 'usa'}}

# %% [markdown]
# ## 4.1). Create a list 'car_brands' of all the makes in the dictionary 'mpg_dict'

# %%
##Begin Solution 

car_brands = list(mpg_dict.keys())
car_brands

##End Solution
# Out:
# ['chevrolet', 'buick', 'plymouth', 'amc', 'ford']

# %% [markdown]
# ## 4.2). Create a list of Tuples containing each Car Make's Name and their corresponding Horsepower

# %%
##Begin Solution 

make_and_horsepower = [(make, mpg_dict[make]['horsepower']) for make in car_brands]
make_and_horsepower

##End Solution
# Out:
# [('chevrolet', 130.0),
#  ('buick', 165.0),
#  ('plymouth', 150.0),
#  ('amc', 150.0),
#  ('ford', 140.0)]

# %% [markdown]
# ## 4.3)  Define a function 'get_cars_origin' that returns a list of car makes of all car makes of a given origin
#
# ### Your function should take two arguments:
#
# A dictionary of car information ('mpg_dict')
# A string containing an origin (for which you are trying to find the car makes' origin)

# %%
##Begin Solution 

def get_cars_origin(mpg_dict, car_origin):
    make_list = []
    car_brands = list(mpg_dict.keys())
    make_list = [make for make in car_brands if mpg_dict[make]['origin']==car_origin]

    return make_list

get_cars_origin(mpg_dict, 'europe')

##End Solution
# Out:
# ['buick']
